# %%
import os 
import time

#import playsound as ps

# define rooms and items
couch = {
    "name": "couch",
    "type": "furniture",
}
door_a = {
    "name": "door a",
    "type": "door",
}
key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}
piano = {
    "name": "piano",
    "type": "furniture",
}
game_room = {
    "name": "game room",
    "type": "room",
}
outside = {
  "name": "outside"
}
bedroom_1 = {
  "name": "bedroom 1",
  "type": "room",
}
bedroom_2 = {
  "name": "bedroom 2",
  "type": "room",
}
door_b = {
    "name": "door b",
    "type": "door",
}
door_c = {
    "name": "door c",
    "type": "door",
}
key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}
key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}
queen_bed = {
    "name": "queen bed",
    "type": "furniture",
}
desk = {
    "name": "desk",
    "type": "furniture",
}
little_girl = {
    "name": "little girl",
    "type": "person",
}
old_person = {
    "name": "old person",
    "type": "person",
}

# Amelie items/characters

groot = {
    "name": "groot",
    "type": "person",
}
 # black whole is door d
black_whole = {
    "name": "black whole",
    "type": "door",
}
# root key is key d
root_key = {
    "name": "key for black whole",
    "type": "key",
    "target": black_whole,
}

rocket = {
    "name": "rocket",
    "type": "person",
}

starlord = {
    "name": "starlord",
    "type": "person",
}

galaxy = {
  "name": "galaxy",
  "type": "room",
}

gamora = {
    "name": "gamora",
    "type": "person",
}

# Daniel items/characters
bedroom_4 = {
  "name": "bedroom 4",
  "type": "room",
}
david_henriques = {
    "name": "David",
    "type": "person",
}
laptop = {
    "name": "laptop",
    "type": "furniture",
}
door_end = {
    "name": "outside gate",
    "type": "door",
}
key_david = {
    "name": "key david",
    "type": "key",
    "target": david_henriques,
}   
key_end = {
    "name": "outside key",
    "type": "key",
    "target": door_end,
}
# End Daniel items/characters


all_rooms = [game_room, bedroom_1, bedroom_2, galaxy, bedroom_4, outside]
all_doors = [door_a, door_b, door_c, black_whole, door_end]

# define which items/rooms are related
object_relations = {
    "game room":    [couch, piano, door_a],
    "piano":        [key_a],    
    "door a":       [game_room, bedroom_1],
    
    "bedroom 1":    [queen_bed, door_a, door_b],
    "queen bed":    [key_b],
    "door b":       [bedroom_1, bedroom_2],
    
    "bedroom 2":    [door_b, door_c, old_person, little_girl, desk],
    "old person":   [key_c],
    "door c":       [bedroom_2, galaxy],
    
    # Amelie relations:
    "galaxy":    [door_c, black_whole, groot, rocket, starlord, gamora],
    "groot":      [root_key],
    "door d":       [galaxy, bedroom_4],
    
    # Daniel relations
    "bedroom 4":    [black_whole, door_end, david_henriques, laptop],
    "laptop":       [key_david],
    "David":        [key_end],
    "outside gate": [outside],
    # End Daniel relations
}

# define game state. Do not directly change this dict.
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

# %%
def linebreak():
    """
    Print a line break
    """
    print("\n\n")
    
def start_game():
    """
    Start the game
    """    
    os.system('cls')
    print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW! \n")
    play_room(game_state["current_room"])
    
def play_room(room):
    """
    Play a room. First check if the room being played is the target room.
    If it is, the game will end with success. Otherwise, let player either
    explore (list all items in this room) or examine an item found here.
    """
    game_state["current_room"] = room
    if(game_state["current_room"] == game_state["target_room"]):
        os.system('cls')
        print("Congrats! You escaped the room and beat the game! \n\n")
        input("Press any key to close the game...")
        time.sleep(3)        
    else:
        print("Current location: " + room["name"] + '\n')
        intended_action = input("What would you like to do? Type 'explore' or 'examine'? \n").strip()        
        if intended_action == "explore":
            explore_room(room)
            play_room(room)
        elif intended_action == "examine":
            examine_item(input("What would you like to examine? \n").strip())
        else:
            print("Not sure what you mean. Type 'explore' or 'examine'. \n")
            play_room(room)
        linebreak()
        
def explore_room(room):
    """
    Explore a room. List all items belonging to this room.
    """
    items = [i["name"] for i in object_relations[room["name"]]]
    print("You explore the room; you find " + ", ".join(items))
    
def get_next_room_of_door(door, current_room):
    """
    From object_relations, find the two rooms connected to the given door.
    Return the room that is not the current_room.
    """
    connected_rooms = object_relations[door["name"]]
    for room in connected_rooms:
        if(not current_room == room):
            return room
            
def examine_item(item_name):
    """
    Examine an item which can be a door or furniture.
    First make sure the intended item belongs to the current room.
    Then check if the item is a door. Tell player if key hasn't been
    collected yet. Otherwise ask player if they want to go to the next
    room. If the item is not a door, then check if it contains keys.
    Collect the key if found and update the game state. At the end,
    play either the current or the next room depending on the game state
    to keep playing.
    """
    current_room = game_state["current_room"]
    next_room = ""
    output = None
    for item in object_relations[current_room["name"]]:
        if(item["name"] == item_name):
            output = "You examine " + item_name + ". "
            if(item["type"] == "door"):
                have_key = False
                for key in game_state["keys_collected"]:
                    if(key["target"] == item):
                        have_key = True
                if(have_key == True):
                    output += "You manage to unlock it with one of the keys. /n"
                    next_room = get_next_room_of_door(item, current_room)
                else:
                    output += "It is locked but you don't have the key. /n"
                    
 #here starts the room of Alicia                   
            else:
                if(item["name"] in object_relations and len(object_relations[item["name"]])>0 and item["name"]=="queen bed"):
                    result_game_key_b=game_key_b()
                    if result_game_key_b==1:
                        item_found = object_relations[item["name"]].pop()
                        game_state["keys_collected"].append(item_found)
                        output += "You win! You find " + item_found["name"] + "."
                    elif result_game_key_b==2:
                        output+= "But you don't want to play. Try again later"
                    elif result_game_key_b==3:
                        output+= "But you have to enter yes/no. Try again later"
                    else:
                        output+= "But your answer is wrong. Try again later"
                        
#Here starts the room of Vanessa 
                elif(item["name"] in object_relations and len(object_relations[item["name"]])>0 and item["name"]=="old person"):
                    result_game_key_c=game_key_c()
                    if result_game_key_c==1:
                        item_found = object_relations[item["name"]].pop()
                        game_state["keys_collected"].append(item_found)
                        output += "You win! You find " + item_found["name"] + "."
                    elif result_game_key_b==2:
                        output+= "But you don't want to play. Try again later"
                    elif result_game_key_b==3:
                        output+= "But you have to enter yes/no. Try again later" 
                    else:
                        output+= "But your answer is wrong. Try again later" 
                        
#Here finished room of Vanessa and start Amelies room
                elif(item["name"] in object_relations and len(object_relations[item["name"]])>0 and item["name"]=="groot"):
                    result_game_root_key=game_root_key()
                    if result_game_root_key==1:
                        item_found = object_relations[item["name"]].pop()
                        game_state["keys_collected"].append(item_found)
                        output += "Congratulations! You win! You find " + item_found["name"] + "."
                    elif result_game_root_key==2:
                        output+= "But you don't want to play. Try again later"
                    elif result_game_root_key==3:
                        output+= "But you have to enter yes/no. Try again later" 
                    else:
                        output+= "But your answer is wrong. Try again later"
#Here finished room of Amelie

#Here finished room of Amelie and start Daniel room

                elif(item["name"] in object_relations and len(object_relations[item["name"]])>0 and item["name"]=="laptop"):
                    result_game_laptop=game_laptop()
                    if result_game_laptop==1:
                        item_found = object_relations[item["name"]].pop()
                        game_state["keys_collected"].append(item_found)
                        output += "You win! You find " + item_found["name"] + "."
                    elif result_game_laptop==2:
                        output+= "But you don't want to play. Try again later"
                    elif result_game_laptop==3:
                        output+= "But you have to enter yes/no. Try again later" 
                    else:
                        output+= "But your answer is wrong. Try again later"
                        
 #Final Boss room                    
                elif(item["name"] in object_relations and len(object_relations[item["name"]])>0 and item["name"]=="David"):
                    result_game_boss=game_boss()
                    if result_game_boss==1:
                        item_found = object_relations[item["name"]].pop()
                        game_state["keys_collected"].append(item_found)
                        output += "You win! You find " + item_found["name"] + "."
                    elif result_game_boss==2:
                        output+= "But you don't want to play. Try again later"
                    elif result_game_boss==3:
                        output+= "But you have to enter yes/no. Try again later"
                    elif result_game_boss==5:
                        output+= "Find the laptop, without it we can't continue!"                        
                    else:
                        output+= "But your answer is wrong. Try again later" 
#Here finished room of Daniel 

                elif(item["name"] in object_relations and len(object_relations[item["name"]])>0 and item["name"]!="queen bed" and item["name"]!="old person" and item["name"]!="p"): #Here you need to add your objets
                    item_found = object_relations[item["name"]].pop()
                    game_state["keys_collected"].append(item_found)
                    output += "You find " + item_found["name"] + "."
                else:
                    output += "There isn't anything interesting about it. \n"
                print(output)
                break                     
    if(output is None):
        print("The item you requested is not found in the current room. \n")
    if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no' \n").strip() == 'yes'):
        play_room(next_room)
    else:
        play_room(current_room)
        
def game_key_b(): #Here is the challege of Alicia 
    answer=input('Something interesting here...Are you ready to play the Quiz ? (yes/no): \n')
    if answer.lower()=='yes':
        answer=input('Question 1: What is your Favourite programming language? \n')
        if answer.lower()=='python':
            return 1
        else:
            return 4
    if answer.lower()=='no':
        return 2
    else:
        return 3
        
def game_key_c(): #Here is the challege of Vanessa
    os.system('cls') # Clears the terminal 
    print_old_person() # Prints Old person Art
    answer=input('Do you think youre clever enough to solve this? (yes/no): \n')
    if answer.lower()=='yes':
        os.system('cls') 
        print_old_person()
        answer=input('Here is the riddle: I look at you, You look at me, I rase my right, you raise yor left, What is this object? \n')
        if answer.lower()=='mirror':
            return 1
        else:
            return 4
    if answer.lower()=='no':
        return 2
    else:
        return 3
        
def game_root_key(): #Here is the challege of Amelie  
    os.system('cls') # Clears the terminal 
    print_groot(): #prints groot 
    answer=input('Hello, my name is groot. I am the boss of the guardians of the galaxy haha. I was told to create a key out of my roots, I don´t know why and I nearly forgot it. I can give it to you if you play a game with me. Are you ready?(yes/no): \n')
    if answer.lower()=='yes':
        answer=input('With whom in the room have I been a baunty haunter before we met starlord? \n')
        if answer.lower()=='rocket':
            return 1
        else:
            return 4
    if answer.lower()=='no':
        return 2
    else:
        return 3

def game_laptop(): #Here is the challege of Daniel  
    answer=input('''You open the laptop, but it's encrypted. You wan to try and unlock it? (yes/no): \n''')
    if answer.lower()=='yes':
        answer=input('''What's the three words that David uses all the time, when something goes well in class? \n''')
        if answer.lower()=='cool' or 'cool cool cool' or 'coolcoolcool':
            return 1
        else:
            return 4
    if answer.lower()=='no':
        return 2
    else:
        return 3  

def game_boss(): #Here is the boss
    have_laptop = False
    for key in game_state["keys_collected"]:
                    if(key["target"] == david_henriques):
                        have_laptop = True
    if have_laptop == True:                   
        answer=input('Cool, Cool, Cool... Glad you could make it, I am the final boss David The Teacher! did you bring your laptop? (yes/no) \n')
    else:
        return 5    
    if answer.lower()=='yes' and have_laptop == True:        
        answer=input('''Let us see if you have learned so far... My final Lab: Remind me of something everyday for every class, if you don't, without IT, my lesson shall be lost. What is it? \n''')
        if answer.lower()=='record' or 'recording' or 'record class':
            return 1
        else:
            return 4
    if answer.lower()=='no':
        return 2
    else:
        return 3   

# ASCII Prinouts start here

def print_title():

    print(r"""
                                              _______________________
   _______________________-------------------                       `\
 /:--__                                                              |
||< > |                                   ___________________________/
| \__/_________________-------------------                         |
|                                                                  |
 |            Welcome to the Ironhack Scape Room                   |
 |                                                                  |
 |      "Three rings for the Elven-kings under the sky,             |
  |        Seven for the Dwarf-lords in their halls of stone,        |
  |      Nine for Mortal Men doomed to die,                          |
  |        One for the Dark Lord on his dark throne                  |
  |      In the Land of Mordor where the Shadows lie.                 |
   |       One Ring to rule them all, One Ring to find them,          |
   |       One Ring to bring them all and in the darkness bind them   |
   |     In the Land of Mordor where the Shadows lie.                |
  |                                              ____________________|_
  |  ___________________-------------------------                      `\
  |/`--_                                                                 |
  ||[ ]||                                            ___________________/
   \===/___________________--------------------------
    """)
    
def print_old_person():
    print(r""" 
                      ,-----.
                     /      |
                    /       |
               ___,'        |
             <  -'          :
              `-.__..--'``-,_\_
                 |o/ ` o  )_`>
                 :/ `     ||/)
                 (_.).__,-` |\
                 /( `.``   `| :
                 \'`-.)  `  ; ;
                 | `       /-<
                 |     `  /   `.
 ,-_-..____     /|  `    :__..-'\
/,'-.__\\  ``-./ :`      ;       \
`\ `\  `\\  \ :  (   `  /  ,   `. \
  \` \   \\   |  | `   :  :     .\ \
   \ `\_  ))  :  ;     |  |      ): :
  (`-.-'\ ||  |\ \   ` ;  ;       | |
   \-_   `;;._   ( `  /  /_       | |
    `-.-.// ,'`-._\__/_,'         ; |
       \:: :     /     `     ,   /  |
    """)    
    

def print_groot():
    print(r"""     .^. .  _    
    /: ||`\/ \~  ,       
  , [   &    / \ y'   
 {v':   `\   / `&~-,  
'y. '    |`   .  ' /   
 \   '  .       , y   
 v .        '     v   
 V  .~.      .~.  V   
 : (  0)    (  0) :   
  i `'`      `'` j     
   i     __    ,j     
    `%`~....~'&         
 <~o' /  \/` \-s,        
  o.~'.  )(  r  .o ,.  
 o',  %``\/``& : 'bF  
d', ,ri.~~-~.ri , +h  
`oso' d`~..~`b 'sos`  
     d`+ II +`b              
     i_:_yi_;_y          """)
     

def print_startgalaxy():
    print(r"""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠀⠀⠈⠉⠉⠛⠛⠷⢶⣤⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣤⣴⣶⣶⣿⣿⣿⣿⣷⣶⣦⣤⣄⡀⠈⠙⠻⣷⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣀⣴⣾⣿⣿⠿⠿⠛⠛⠛⠛⠻⠿⠿⣿⣿⣿⣿⣿⣷⣤⡀⠀⠙⢿⣷⣄⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⢀⣴⣾⠿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠻⣿⣿⣿⣿⣷⡄⠀⠙⢿⣷⡀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⢀⣴⡿⠛⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠙⢿⣿⣿⣿⣦⠀⠈⢿⣿⡄⠀⠀⠀⠀⠀
⠀⠀⣠⡾⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠒⠒⠒⠤⣄⣀⠀⠀⠀⠻⣿⣿⣿⣷⡀⠀⢿⣿⡀⠀⠀⠀⠀
⠀⣰⠟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣤⣴⣶⣶⣶⣶⣶⣦⣤⡀⠉⠳⣦⡀⠀⠘⣿⣿⣿⣧⠀⠈⣿⣇⠀⠀⠀⠀
⢰⠏⠀⠀⠀⠀⠀⠀⢀⠔⠀⣠⣴⣿⣿⡿⠛⠋⠉⠉⠉⠉⠙⠻⣿⣷⡀⠈⢷⡀⠀⠸⣿⣿⣿⡄⠀⢹⣿⠀⠀⠀⠀
⠏⠀⠀⠀⠀⠀⢀⡴⠃⢀⣼⣿⣿⠟⠁⠀⠀⡀⠀⢀⣠⣤⡤⣤⡈⢻⣿⡀⠘⣇⠀⠀⣿⣿⣿⡇⠀⢸⣿⠀⠀⠀⠀
⠀⠀⠀⠀⠀⢠⡞⠀⢠⣿⣿⡿⠁⠀⢀⡴⠊⣠⡾⠋⠉⠀⠀⠀⡟⢈⣿⡇⢠⡟⠀⠀⣿⣿⣿⠃⠀⣸⡏⠀⠀⠀⠀
⠀⠀⠀⠀⢠⡟⠀⢀⣿⣿⡿⠀⠀⢠⡏⢠⣾⠏⢀⡠⢲⡖⢀⡜⠁⣼⡿⠀⣼⠃⠀⢰⣿⣿⡿⠀⢀⡿⠁⠀⠀⠀⠀
⠀⠀⠀⠀⣿⠃⠀⣼⣿⣿⡇⠀⢠⡿⠀⣾⡏⢀⡎⠀⠈⠉⠁⢀⣼⠟⢁⡼⠁⠀⢀⣾⣿⡿⠁⠀⡾⠁⠀⠀⠀⠀⠀
⠀⠀⠀⢸⣿⠀⠀⣿⣿⣿⡇⠀⢸⡇⠀⣿⣧⠸⣧⣤⣤⣴⠾⠛⠁⠐⠁⠀⠀⣠⣾⣿⡟⠁⢀⡞⠁⠀⠀⠀⠀⠀⡄
⠀⠀⠀⢸⣿⠀⠀⣿⣿⣿⡇⠀⠈⣷⡀⠹⣿⣦⣀⠀⠀⠀⠀⠀⠀⠀⣀⣤⣾⣿⡿⠋⢀⡴⠋⠀⠀⠀⠀⠀⠀⣰⠃
⠀⠀⠀⢸⣿⡄⠀⢹⣿⣿⣿⡀⠀⠘⢷⡄⠈⠻⢿⣿⣶⣶⣶⣶⣾⣿⣿⡿⠟⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⠃⠀
⠀⠀⠀⠈⣿⣧⠀⠈⢿⣿⣿⣷⡄⠀⠀⠙⠳⠤⣀⣈⠉⠉⠙⠋⠉⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣾⠃⠀⠀
⠀⠀⠀⠀⠘⣿⣧⠀⠈⢿⣿⣿⣿⣦⡀⠀⠀⠀⠀⠀⠈⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣾⡟⠁⠀⠀⠀
⠀⠀⠀⠀⠀⠙⣿⣧⡀⠀⠻⣿⣿⣿⣿⣦⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣤⣾⡿⠋⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠈⠻⣿⣆⠀⠈⠻⢿⣿⣿⣿⣿⣶⣤⣄⣀⡀⠀⠀⠀⠀⢀⣀⣀⣤⣶⣾⡿⠟⠉⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣷⣦⣀⠀⠉⠻⠿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠛⠷⣦⣤⣀⠀⠈⠉⠉⠙⠛⠛⠛⠉⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠛⠛⠒⠒⠒⠒⠒⠒⠒⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀""")

game_state = INIT_GAME_STATE.copy()

os.system('mode con: cols=75 lines=40')

print_title() 
time.sleep(4)
input("Press Enter to continue...")
start_game()
